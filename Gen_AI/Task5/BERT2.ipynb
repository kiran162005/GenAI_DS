# %% [markdown]
# # ASSIGNMENT NLP-5: Fine-Tuning BERT for POS Tagging & Chunking

# %% [markdown]
# # Fine-Tuning BERT for POS Tagging (Token Classification)
#
# This project focuses on building a token classification model using BERT to perform Part-of-Speech (POS) tagging.
#
# The model is trained on the Universal Dependencies dataset and evaluated using sequence-based metrics.

# %% [markdown]
# ## Objective
#
# The goal of this assignment is to fine-tune a transformer-based model (BERT) to perform Part-of-Speech (POS) tagging.
#
# This involves:
# - Token classification using BERT
# - Handling tokenization and label alignment
# - Training and evaluating the model
# - Performing inference on custom sentences

# %% [markdown]
# ## 1. Dataset Selection
#
# Dataset: Universal Dependencies (UD)
#
# Task: Part-of-Speech (POS) Tagging
#
# Labels:
# NOUN, VERB, ADJ, ADV, PRON, DET, ADP, NUM, CONJ, PUNCT, etc.

# %% [markdown]
# # 2. Install & Import

# %%
# !pip install transformers datasets seqeval
# Out:
# Requirement already satisfied: transformers in c:\users\kiran t\anaconda3\lib\site-packages (5.5.0)
# Requirement already satisfied: datasets in c:\users\kiran t\anaconda3\lib\site-packages (2.19.2)
# Requirement already satisfied: seqeval in c:\users\kiran t\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in c:\users\kiran t\anaconda3\lib\site-packages (from transformers) (1.8.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\kiran t\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kiran t\anaconda3\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\kiran t\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\kiran t\anaconda3\lib\site-packages (from transformers) (2026.3.32)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\kiran t\anaconda3\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in c:\users\kiran t\anaconda3\lib\site-packages (from transformers) (0.9.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\kiran t\anaconda3\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\kiran t\anaconda3\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: filelock in c:\users\kiran t\anaconda3\lib\site-packages (from datasets) (3.13.1)
# Requirement already satisfied: pyarrow>=12.0.0 in c:\users\kiran t\anaconda3\lib\site-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in c:\users\kiran t\anaconda3\lib\site-packages (from datasets) (0.7)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\kiran t\anaconda3\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\kiran t\anaconda3\lib\site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.1 in c:\users\kiran t\anaconda3\lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: xxhash in c:\users\kiran t\anaconda3\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess in c:\users\kiran t\anaconda3\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in c:\users\kiran t\anaconda3\lib\site-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets) (2024.3.1)
# Requirement already satisfied: aiohttp in c:\users\kiran t\anaconda3\lib\site-packages (from datasets) (3.10.5)
# Requirement already satisfied: scikit-learn>=0.21.3 in c:\users\kiran t\anaconda3\lib\site-packages (from seqeval) (1.5.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\kiran t\anaconda3\lib\site-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\kiran t\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kiran t\anaconda3\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kiran t\anaconda3\lib\site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kiran t\anaconda3\lib\site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\kiran t\anaconda3\lib\site-packages (from aiohttp->datasets) (1.11.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in c:\users\kiran t\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\kiran t\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.27.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\kiran t\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kiran t\anaconda3\lib\site-packages (from requests>=2.32.1->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kiran t\anaconda3\lib\site-packages (from requests>=2.32.1->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kiran t\anaconda3\lib\site-packages (from requests>=2.32.1->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kiran t\anaconda3\lib\site-packages (from requests>=2.32.1->datasets) (2026.2.25)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\kiran t\anaconda3\lib\site-packages (from scikit-learn>=0.21.3->seqeval) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kiran t\anaconda3\lib\site-packages (from scikit-learn>=0.21.3->seqeval) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\kiran t\anaconda3\lib\site-packages (from scikit-learn>=0.21.3->seqeval) (3.5.0)
# Requirement already satisfied: colorama in c:\users\kiran t\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kiran t\anaconda3\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kiran t\anaconda3\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kiran t\anaconda3\lib\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\kiran t\anaconda3\lib\site-packages (from typer->transformers) (8.1.7)
# Requirement already satisfied: anyio in c:\users\kiran t\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\kiran t\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\kiran t\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\kiran t\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.14.0)
# Requirement already satisfied: six>=1.5 in c:\users\kiran t\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
# !pip uninstall pyarrow -y
# !pip install pyarrow==14.0.2
# Out:
# Found existing installation: pyarrow 14.0.2
# Uninstalling pyarrow-14.0.2:
#   Successfully uninstalled pyarrow-14.0.2
# Collecting pyarrow==14.0.2
#   Using cached pyarrow-14.0.2-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\kiran t\anaconda3\lib\site-packages (from pyarrow==14.0.2) (1.26.4)
# Using cached pyarrow-14.0.2-cp312-cp312-win_amd64.whl (25.0 MB)
# Installing collected packages: pyarrow
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 23.0.1
#     Uninstalling pyarrow-23.0.1:
#       Successfully uninstalled pyarrow-23.0.1
# Successfully installed pyarrow-14.0.2
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Kiran T\anaconda3\Lib\site-packages\~yarrow.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Kiran T\AppData\Local\Temp\pip-uninstall-6tlcqqkz'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.37.1 requires protobuf<6,>=3.20, but you have protobuf 6.33.5 which is incompatible.

# %%
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForTokenClassification, TrainingArguments, Trainer
import numpy as np
from seqeval.metrics import classification_report

# %% [markdown]
# # 3. Load Dataset

# %%
dataset = load_dataset("universal_dependencies", "en_ewt")
# Out:
# C:\Users\Kiran T\anaconda3\Lib\site-packages\datasets\load.py:1491: FutureWarning: The repository for universal_dependencies contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/universal_dependencies
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading readme: 0.00B [00:00, ?B/s]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 dataset = load_dataset("universal_dependencies", "en_ewt")
#
# File ~\anaconda3\Lib\site-packages\datasets\load.py:2592, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2587 verification_mode = VerificationMode(
#    2588     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2589 )
#    2591 # Create a dataset builder
# -> 2592 builder_instance = load_dataset_builder(
#    2593     path=path,
#    2594     name=name,
#    2595     data_dir=data_dir,
#    2596     data_files=data_files,
#    2597     cache_dir=cache_dir,
#    2598     features=features,
#    2599     download_config=download_config,
#    2600     download_mode=download_mode,
#    2601     revision=revision,
#    2602     token=token,
#    2603     storage_options=storage_options,
#    2604     trust_remote_code=trust_remote_code,
#    2605     _require_default_config_name=name is None,
#    2606     **config_kwargs,
#    2607 )
#    2609 # Return iterable dataset in case of streaming
#    2610 if streaming:
#
# File ~\anaconda3\Lib\site-packages\datasets\load.py:2264, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, use_auth_token, storage_options, trust_remote_code, _require_default_config_name, **config_kwargs)
#    2262     download_config = download_config.copy() if download_config else DownloadConfig()
#    2263     download_config.storage_options.update(storage_options)
# -> 2264 dataset_module = dataset_module_factory(
#    2265     path,
#    2266     revision=revision,
#    2267     download_config=download_config,
#    2268     download_mode=download_mode,
#    2269     data_dir=data_dir,
#    2270     data_files=data_files,
#    2271     cache_dir=cache_dir,
#    2272     trust_remote_code=trust_remote_code,
#    2273     _require_default_config_name=_require_default_config_name,
#    2274     _require_custom_configs=bool(config_kwargs),
#    2275 )
#    2276 # Get dataset builder class from the processing script
#    2277 builder_kwargs = dataset_module.builder_kwargs
#
# File ~\anaconda3\Lib\site-packages\datasets\load.py:1915, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, cache_dir, trust_remote_code, _require_default_config_name, _require_custom_configs, **download_kwargs)
#    1910             if isinstance(e1, FileNotFoundError):
#    1911                 raise FileNotFoundError(
#    1912                     f"Couldn't find a dataset script at {relative_to_absolute_path(combined_path)} or any data file in the same directory. "
#    1913                     f"Couldn't find '{path}' on the Hugging Face Hub either: {type(e1).__name__}: {e1}"
#    1914                 ) from None
# -> 1915             raise e1 from None
#    1916 else:
#    1917     raise FileNotFoundError(
#    1918         f"Couldn't find a dataset script at {relative_to_absolute_path(combined_path)} or any data file in the same directory."
#    1919     )
#
# File ~\anaconda3\Lib\site-packages\datasets\load.py:1888, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, cache_dir, trust_remote_code, _require_default_config_name, _require_custom_configs, **download_kwargs)
#    1879             pass
#    1880     # Otherwise we must use the dataset script if the user trusts it
#    1881     return HubDatasetModuleFactoryWithScript(
#    1882         path,
#    1883         revision=revision,
#    1884         download_config=download_config,
#    1885         download_mode=download_mode,
#    1886         dynamic_modules_path=dynamic_modules_path,
#    1887         trust_remote_code=trust_remote_code,
# -> 1888     ).get_module()
#    1889 else:
#    1890     return HubDatasetModuleFactoryWithoutScript(
#    1891         path,
#    1892         revision=revision,
#    (...)
#    1896         download_mode=download_mode,
#    1897     ).get_module()
#
# File ~\anaconda3\Lib\site-packages\datasets\load.py:1503, in HubDatasetModuleFactoryWithScript.get_module(self)
#    1501 dataset_readme_path = self.download_dataset_readme_file()
#    1502 imports = get_imports(local_path)
# -> 1503 local_imports = _download_additional_modules(
#    1504     name=self.name,
#    1505     base_path=hf_dataset_url(self.name, "", revision=self.revision),
#    1506     imports=imports,
#    1507     download_config=self.download_config,
#    1508 )
#    1509 additional_files = []
#    1510 if dataset_infos_path:
#
# File ~\anaconda3\Lib\site-packages\datasets\load.py:353, in _download_additional_modules(name, base_path, imports, download_config)
#     351     if "Bio" in needs_to_be_installed.keys():
#     352         needs_to_be_installed["Bio"] = "biopython"
# --> 353     raise ImportError(
#     354         f"To be able to use {name}, you need to install the following {_dependencies_str}: "
#     355         f"{', '.join(needs_to_be_installed)}.\nPlease install {_them_str} using 'pip install "
#     356         f"{' '.join(needs_to_be_installed.values())}' for instance."
#     357     )
#     358 return local_imports
#
# ImportError: To be able to use universal_dependencies, you need to install the following dependency: conllu.
# Please install it using 'pip install conllu' for instance.
