# %% [markdown]
# # Chatbot using Hugging Face Transformers

# %% [markdown]
# # Chatbot using Transformers (GPT-2)
#
# This project implements a conversational chatbot using a pre-trained GPT-2 model from Hugging Face.

# %% [markdown]
# ## Objective
#
# To build a chatbot using a transformer-based model that can generate meaningful responses and interact with users in natural language.

# %% [markdown]
# ## Install required libraries

# %%
# !pip install transformers torch

# %% [markdown]
# ## Import libraries

# %%
# Import required libraries
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %% [markdown]
# ## Load pre-trained model & tokenizer

# %%
model_name = "microsoft/DialoGPT-medium"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
# Out:
# ...
# Loading weights:   0%|          | 0/293 [00:00<?, ?it/s]

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# Load model
model_name = "microsoft/DialoGPT-medium"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# Set device
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)

print("🤖 SmartBot: Hello! I'm your AI assistant. Ask me anything (type 'exit' to quit)\n")

chat_history_ids = None

# Personality prompt (makes chatbot better)
personality = "You are a helpful, polite and intelligent AI assistant."

while True:
    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit"]:
        print("🤖 SmartBot: Goodbye! It was nice chatting with you 😊")
        break

    # Add personality context
    prompt = personality + " User: " + user_input

    # Encode
    new_input_ids = tokenizer.encode(prompt + tokenizer.eos_token, return_tensors='pt').to(device)

    # Attention mask
    if chat_history_ids is not None:
        bot_input_ids = torch.cat([chat_history_ids, new_input_ids], dim=-1)
    else:
        bot_input_ids = new_input_ids

    attention_mask = torch.ones(bot_input_ids.shape, dtype=torch.long).to(device)

    # Generate response (better tuned)
    chat_history_ids = model.generate(
        bot_input_ids,
        attention_mask=attention_mask,
        max_length=1000,
        pad_token_id=tokenizer.eos_token_id,
        do_sample=True,
        top_k=40,
        top_p=0.9,
        temperature=0.6,
        repetition_penalty=1.2
    )

    # Decode response
    response = tokenizer.decode(
        chat_history_ids[:, bot_input_ids.shape[-1]:][0],
        skip_special_tokens=True
    )

    print(f"🤖 SmartBot: {response}\n")
# Out:
# Loading weights:   0%|          | 0/293 [00:00<?, ?it/s]
# 🤖 SmartBot: Hello! I'm your AI assistant. Ask me anything (type 'exit' to quit)
# You:  hello
# 🤖 SmartBot: I'm sorry, but I have no idea what that means.

# %% [markdown]
# ## Sample Output
#
# Chatbot: Hello! I am your AI assistant. Type 'exit' to end.
#
# You: Hello
# Chatbot: Hi! How can I help you today?
#
# You: What is Artificial Intelligence?
# Chatbot: Artificial Intelligence refers to machines that can simulate human intelligence.
#
# You: Who created Python?
# Chatbot: Python was created by Guido van Rossum.
#
# You: exit
# Chatbot: Goodbye!
