# %% [markdown]
# # GenAI – Prompt Engineering: LangChain Prompt Templates
#
# **Objective:** Build dynamic and reusable prompt systems using LangChain instead of hardcoded prompts.
#
# **Pipeline Flow:** User Input → Validation → Prompt Template → Dynamic Prompt Generation → Output

# %% [markdown]
# ## Setup – Install and Import Required Libraries

# %%
# !pip install langchain langchain-core
# Out:
# Requirement already satisfied: langchain in c:\users\kiran t\anaconda3\lib\site-packages (1.2.15)
# Requirement already satisfied: langchain-core in c:\users\kiran t\anaconda3\lib\site-packages (1.2.28)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in c:\users\kiran t\anaconda3\lib\site-packages (from langchain) (1.1.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\kiran t\anaconda3\lib\site-packages (from langchain) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\kiran t\anaconda3\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\kiran t\anaconda3\lib\site-packages (from langchain-core) (0.7.29)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\kiran t\anaconda3\lib\site-packages (from langchain-core) (24.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\kiran t\anaconda3\lib\site-packages (from langchain-core) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\kiran t\anaconda3\lib\site-packages (from langchain-core) (8.2.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\kiran t\anaconda3\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\kiran t\anaconda3\lib\site-packages (from langchain-core) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\kiran t\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (2.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\kiran t\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in c:\users\kiran t\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\kiran t\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\kiran t\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\kiran t\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.27.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\kiran t\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\kiran t\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\kiran t\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.3)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\kiran t\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.23.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\kiran t\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\kiran t\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.20.1)
# Requirement already satisfied: anyio in c:\users\kiran t\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (4.2.0)
# Requirement already satisfied: certifi in c:\users\kiran t\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\kiran t\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.2)
# Requirement already satisfied: idna in c:\users\kiran t\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.7)
# Requirement already satisfied: sniffio in c:\users\kiran t\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\kiran t\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.14.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\kiran t\anaconda3\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kiran t\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kiran t\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.2.3)

# %%
# Import required modules from LangChain
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate
from langchain_core.prompts import HumanMessagePromptTemplate, SystemMessagePromptTemplate

# %% [markdown]
# ---
# ## Task 1: Replace Hardcoded Prompts
#
# Convert the given f-string function into a reusable LangChain `PromptTemplate`.

# %%
template_1 = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms for beginners"
)

# Test
print(template_1.format(topic="AI"))
# Out:
# Explain AI in simple terms for beginners

# %% [markdown]
# ---
# ## Task 2: Multi-Input Prompt System
#
# Build a template that accepts `topic`, `audience`, and `tone` as inputs.

# %%
template_2 = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template="Explain {topic} for {audience} in a {tone} tone"
)

# Test cases
print(template_2.format(topic="AI", audience="beginners", tone="friendly"))
print(template_2.format(topic="Python", audience="kids", tone="fun"))
print(template_2.format(topic="Deep Learning", audience="engineers", tone="technical"))
# Out:
# Explain AI for beginners in a friendly tone
# Explain Python for kids in a fun tone
# Explain Deep Learning for engineers in a technical tone

# %% [markdown]
# ---
# ## Task 3: Prompt Variations Engine
#
# Create 3 distinct `PromptTemplate` objects – Teaching, Interview, and Storytelling.

# %%
teaching_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} clearly step by step"
)

interview_template = PromptTemplate(
    input_variables=["topic"],
    template="Ask 3 questions about {topic}"
)

story_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} as a story"
)

topic = "Machine Learning"

print(teaching_template.format(topic=topic))
print(interview_template.format(topic=topic))
print(story_template.format(topic=topic))
# Out:
# Explain Machine Learning clearly step by step
# Ask 3 questions about Machine Learning
# Explain Machine Learning as a story
