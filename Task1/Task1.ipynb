# %% [markdown]
# 1. User Login Check
# Problem Statement:
# Given a username and password, check whether login is successful.
# username = "admin"
# password = "1234"
#
# Requirements:
# Print "Login Successful" if both username and password match
# Otherwise print "Invalid Credentials"
# Real-World Application: Authentication systems

# %%
username = "admin"
password = "1234"

input_username = "admin"   # You can change for testing
input_password = "1234"    # You can change for testing

if input_username == username and input_password == password:
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Invalid Credentials

# %% [markdown]
# 2. Pass / Fail Analyzer
# Problem Statement:
# Analyze student results.
# marks = [45, 78, 90, 33, 60]
#
# Requirements:
# A student passes if marks ≥ 50
# Count the total number of pass students
# Count the total number of fail students
# Print the final result clearly
# Real-World Application: Academic evaluation systems

# %%
marks = [45, 78, 90, 33, 60]

pass_count = 0
fail_count = 0

for mark in marks:
    if mark >= 50:
        print("pass")
        pass_count+=1
    else:
        print("fail")
        fail_count+=1

print("Total Students:", len(marks))
print("Passed:", pass_count)
print("Failed:", fail_count)
# Out:
# fail
# pass
# pass
# fail
# pass
# Total Students: 5
# Passed: 3
# Failed: 2

# %% [markdown]
# 3. Simple Data Cleaner
# Problem Statement:
# Clean and standardize user names.
# names = [" Alice ", "bob", " CHARLIE "]
#
# Requirements:
# Remove extra spaces
# Convert all names to lowercase
# Print the cleaned list
# Real-World Application: Data preprocessing before analysis

# %%
names = [" Alice ", "bob", " CHARLIE "]

cleaned_names = []

for name in names:
    cleaned_name = name.strip().lower()
    cleaned_names.append(cleaned_name)

print(f"Cleaned Name Lists {cleaned_names}")
# Out:
# Cleaned Name Lists ['alice', 'bob', 'charlie']

# %% [markdown]
# 4. Message Length Analyzer
# Problem Statement:
# Analyze message sizes.
# messages = ["Hi", "Welcome to the platform", "OK"]
#
# Requirements:
# Print the length of each message
# Flag messages longer than 10 characters
# Real-World Application: Text filtering and validation systems

# %%
messages = ["Hi", "Welcome to the platform", "OK"]

print(f"Number of messages: {len(messages)}")

for message in messages:
    length = len(message)
    print(f"Message: {message} || Length: {length}")
    
    if length > 10:
        print("Flag: Message longer than 10 words")
    else:
        print("Normal message")
# Out:
# Number of messages: 3
# Message: Hi || Length: 2
# Normal message
# Message: Welcome to the platform || Length: 23
# Flag: Message longer than 10 words
# Message: OK || Length: 2
# Normal message

# %% [markdown]
# 5. Error Message Detector
# Problem Statement:
# Detect error messages from system logs.
# logs = ["INFO", "ERROR", "WARNING", "ERROR"]
#
# Requirements:
# Count the number of "ERROR" entries
# Print the total error count
# Real-World Application: Monitoring and log analysis systems

# %%
logs = ["INFO", "ERROR", "WARNING", "ERROR"]

error=0

for log in logs:
    if log == "ERROR":
        error += 1

print("Total ERROR entries: ",error)
# Out:
# Total ERROR entries:  2
